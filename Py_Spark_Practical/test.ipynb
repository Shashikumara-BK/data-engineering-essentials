# %%
# %sql
create table data_dev_cataolog.default.test(
  id integer,
  name string
)
using delta

# %%
# %sql
insert into data_dev_cataolog.default.test values(1,'shashi')

# %%
# %sql
select * from data_dev_cataolog.default.test

# %%
# %sql
drop table data_dev_cataolog.default.test

# %%
# %sql
select * from data_dev_cataolog.default.test

# %%
# %sql
create table data_dev_cataolog.default.test(
  id integer,
  name string
)
using delta
location ""

# %%
# %sql
create volume data_dev_cataolog.default.test_volume
