# %%
import json

def get_column_names(schemas, ds_name, sorting_key='column_position'):
    column_details = schemas[ds_name]
    columns = sorted(column_details, key=lambda col: col[sorting_key])
    return [col['column_name'] for col in columns]

# %%
schemas = json.load(open('data/retail_db/schemas.json'))

# %%
import glob

# %%
src_file_names = glob.glob('data/retail_db/*/part*')

# %%
src_file_names
# Out:
# ['data/retail_db\\categories\\part-00000',
#  'data/retail_db\\customers\\part-00000',
#  'data/retail_db\\departments\\part-00000',
#  'data/retail_db\\orders\\part-00000',
#  'data/retail_db\\order_items\\part-00000',
#  'data/retail_db\\products\\part-00000']

# %%
s = 's/a \\b\\c'

# %%
s.split(' ')
# Out:
# ['s/a', '\\b\\c']

# %%
s.split('\\')
# Out:
# ['s/a ', 'b', 'c']

# %%
import re

# %%
re.split(r'[/\\]',s)
# Out:
# ['s', 'a ', 'b', 'c']

# %%
for file in src_file_names:
    print(re.split(r'[/\\]',file))
# Out:
# ['data', 'retail_db', 'categories', 'part-00000']
# ['data', 'retail_db', 'customers', 'part-00000']
# ['data', 'retail_db', 'departments', 'part-00000']
# ['data', 'retail_db', 'orders', 'part-00000']
# ['data', 'retail_db', 'order_items', 'part-00000']
# ['data', 'retail_db', 'products', 'part-00000']

# %%
file = src_file_names[1]

# %%
file
# Out:
# 'data/retail_db\\customers\\part-00000'

# %%
file_details= re.split(r'[/\\]', file)

# %%
file_details
# Out:
# ['data', 'retail_db', 'customers', 'part-00000']

# %%
ds_name = file_details[-2]

# %%
columns = get_column_names(schemas , ds_name)

# %%
import pandas as pd

# %%
df = pd.read_csv(file, names=columns)

# %%
df
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# ...

# %%
df.shape
# Out:
# (12435, 9)

# %%
file_path_list = re.split('[/\\\]', file)
print(f"{src_file_names} converted file path to list of string {file_path_list}")
# Out:
# ['data/retail_db\\categories\\part-00000', 'data/retail_db\\customers\\part-00000', 'data/retail_db\\departments\\part-00000', 'data/retail_db\\orders\\part-00000', 'data/retail_db\\order_items\\part-00000', 'data/retail_db\\products\\part-00000']converted file path to list of string ['data', 'retail_db', 'products', 'part-00000']

# %%
for file in src_file_names:
    print(f'Processing {file}')
    file_path_list = re.split('[/\\\]', file)
    print(f"'data/retail_db\\categories\\part-00000' \n converted file path to list of string \n {file_path_list}\n")
    ds_name = file_path_list[-2]
    print('ds name = ',ds_name)
    columns = get_column_names(schemas, ds_name)
    df = pd.read_csv(file, names=columns)
    print(f'Shape of {ds_name} is {df.shape}')
# Out:
# Processing data/retail_db\categories\part-00000
# 'data/retail_db\categories\part-00000'
#  converted file path to list of string
#  ['data', 'retail_db', 'categories', 'part-00000']
#
# ds name =  categories
# Shape of categories is (58, 3)
# Processing data/retail_db\customers\part-00000
# 'data/retail_db\categories\part-00000'
#  converted file path to list of string
#  ['data', 'retail_db', 'customers', 'part-00000']
#
# ds name =  customers
# Shape of customers is (12435, 9)
# Processing data/retail_db\departments\part-00000
# 'data/retail_db\categories\part-00000'
#  converted file path to list of string
#  ['data', 'retail_db', 'departments', 'part-00000']
#
# ds name =  departments
# Shape of departments is (6, 2)
# Processing data/retail_db\orders\part-00000
# 'data/retail_db\categories\part-00000'
#  converted file path to list of string
#  ['data', 'retail_db', 'orders', 'part-00000']
#
# ds name =  orders
# Shape of orders is (68883, 4)
# ...

# %%
df
# Out:
#       product_id  product_cateogry_id  \
# 0              1                    2
# 1              2                    2
# 2              3                    2
# 3              4                    2
# 4              5                    2
# ...          ...                  ...
# 1340        1341                   59
# 1341        1342                   59
# 1342        1343                   59
# 1343        1344                   59
# 1344        1345                   59
#
#                                        product_name  product_description  \
# 0     Quest Q64 10 FT. x 10 FT. Slant Leg Instant U                  NaN
# 1     Under Armour Men's Highlight MC Football Clea                  NaN
# 2     Under Armour Men's Renegade D Mid Football Cl                  NaN
# 3     Under Armour Men's Renegade D Mid Football Cl                  NaN
# 4     Riddell Youth Revolution Speed Custom Footbal                  NaN
# ...
