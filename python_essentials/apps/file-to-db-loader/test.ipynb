# %%
l = [1,2,4,3,5,6,6,8,3]

# %%
import time

# %%
for i in l:
    print(f"sleeping for {i}")
    time.sleep(i)
# Out:
# sleeping for 1
# sleeping for 2
# sleeping for 4
# sleeping for 3
# sleeping for 5
# sleeping for 6
# sleeping for 6
# sleeping for 8
# sleeping for 3

# %%
import multiprocessing

# %%
pool = multiprocessing.Pool(8)

# %%
pool.map(time.sleep, l)
# Out:
# [None, None, None, None, None, None, None, None, None]

# %%
from mpdemo import mySleep

# %%
mySleep(2)
# Out:
# sleep for 2

# %%
pool.map(mySleep,l)
# Out:
# [None, None, None, None, None, None, None, None, None]

# %%
from app import process_files

# %%
process_files()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 process_files()
#
# File d:\DEVOPS_PROJECTS\DATA_Engineering\python_essentials\apps\file-to-db-loader\app.py:68, in process_files(ds_names)
#      66 db_pass = os.environ.get('DB_PASS')
#      67 db_conn_uri = f'postgresql://{db_user}:{db_pass}@{db_host}:{db_port}/{db_name}'
# ---> 68 schemas = json.load(open(f'{src_base_dir}/schemas.json'))
#      69 if not ds_names:
#      70     ds_names = schemas.keys()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'None/schemas.json'
