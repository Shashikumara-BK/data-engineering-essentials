# %%
# Required for Notebook to use SQL Magic
# Facilitates to run queries from Notebooks 
# without using Python Code
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Collecting prettytable
#   Downloading prettytable-3.16.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: ipython in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (9.3.0)
# Collecting sqlalchemy>=2.0
#   Downloading sqlalchemy-2.0.41-cp311-cp311-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 5.4 MB/s eta 0:00:00
# Collecting sqlparse
#   Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.4/44.4 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: six in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting greenlet>=1
#   Downloading greenlet-3.2.3-cp311-cp311-win_amd64.whl (297 kB)
#      -------------------------------------- 297.0/297.0 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.14.0)
# Requirement already satisfied: colorama in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from stack_data->ipython->ipython-sql) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
# Installing collected packages: ipython-genutils, sqlparse, prettytable, greenlet, sqlalchemy, ipython-sql
# Successfully installed greenlet-3.2.3 ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.16.0 sqlalchemy-2.0.41 sqlparse-0.5.3
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Native Postgres Library to connect to Posgres Database Server
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.10
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# SQLAlchemy is ORM and needs native database libraries (psycopg2)
# Pandas internally uses SQL Alchemy to connect to database
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (2.0.41)
# Requirement already satisfied: greenlet>=1 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from sqlalchemy) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from sqlalchemy) (4.14.0)
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (3.16.0)
# Requirement already satisfied: ipython in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (9.3.0)
# Requirement already satisfied: sqlalchemy>=2.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (2.0.41)
# Requirement already satisfied: sqlparse in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.14.0)
# Requirement already satisfied: colorama in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from stack_data->ipython->ipython-sql) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip show ipython-sql
# Out:
# Name: ipython-sql
# Version: 0.5.0
# Summary: RDBMS access via IPython
# Home-page: https://github.com/catherinedevlin/ipython-sql
# Author: Catherine Devlin
# Author-email: catherine.devlin@gmail.com
# License: MIT
# Location: d:\DEVOPS_PROJECTS\DATA_Engineering\pr-venv\Lib\site-packages
# Requires: ipython, ipython-genutils, prettytable, six, sqlalchemy, sqlparse
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install prettytable==3.7.0
# Out:
# Collecting prettytable==3.7.0
#   Downloading prettytable-3.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wcwidth in d:\devops_projects\data_engineering\pr-venv\lib\site-packages (from prettytable==3.7.0) (0.2.13)
# Installing collected packages: prettytable
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.16.0
#     Uninstalling prettytable-3.16.0:
#       Successfully uninstalled prettytable-3.16.0
# Successfully installed prettytable-3.7.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
